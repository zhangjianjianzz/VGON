# %%
import torch

# %%
activation_dict = {
    "relu": torch.nn.ReLU(),
    "gelu": torch.nn.GELU(),
    "sigmoid": torch.nn.Sigmoid(),
}

# %%
from src import  BaseMLPModel

# %%
from torch import nn

x = BaseMLPModel(
    encoders=[25,20],
    decoders=[20,25],
    activation=nn.ReLU(),
)
x.layers[f"encoder_{1-1}"]
# Out:
# Linear(in_features=25, out_features=20, bias=True)
